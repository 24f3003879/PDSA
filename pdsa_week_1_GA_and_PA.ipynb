# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh-q10/PDSA/blob/main/pdsa_week_1_GA_and_PA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GRADED ASSIGNMENT WEEK - 1

# %% [markdown]
# QUESTION-1

# %%
def fun(S):
  p = 0
  S = S.lower()
  for i in range(len(S)):
    if S[i] not in S[:i]:
      p += 1
  return p

print(fun("ankitankit"))
print(fun("abchgdyiijdejf"))

# this function is returning total number of distinct letters in the string S
# Out:
# 5
# 11

# %% [markdown]
# QUESTION-3

# %%
def f(n):
  s = 0
  for i in range(2, n):
    if n % i == 0 and i % 2 == 1:
      s = s + 1
  return(s)

print(f(60) - f(59))
# Out:
# 3

# %% [markdown]
# QUESTION-4

# %%
x = 1
while True:
  if x % 5 = = 0:
    break
  print(x, end = ' ')
  x + = 1
# Out:
#   File "/tmp/ipykernel_2978/3633061749.py", line 3
#     if x % 5 = = 0:
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# QUESTION-5

# %%
class Person:
  def __init__(self, name):
    self.name = name
  def say_hi(self):
    print("Hello, ", self.name)

p = Person('Good morning')
p.say_hi()
# Out:
# Hello,  Good morning

# %% [markdown]
# QUESTION-6

# %%
a = [1, 2, 3]
try:
  print("second element = %d" %(a[1]))
  print("Fourth element = %d" %(a[3]))
except:
  print("An error occured")
# Out:
# second element = 2
# An error occured

# %% [markdown]
# QUESTION-7

# %%
def special3Bad(L):
  try:
    if L[0] % L[1] == 0 and L[1] != 0:
      if L[0] / (L[1] ** 2 - L[2]) == 0:
        return True
      return False
  except ZeroDivisionError:
    print("ZeroDivisionError")
  except:
    print("Some other exception occured")
  else:
    print("No exception occured")


special3Bad([44, 6, 36])
# Out:
# No exception occured

# %% [markdown]
# QUESTION-8

# %%
def isSymmetricBad(L):
  try:
    while len(L) > 0:
      if L.pop(0) != L.pop(-1):
        return False
    return True
  except IndexError:
    print("IndexError")
  except:
    print("Some other exception occured")
  else:
    print('No exception occured')



isSymmetricBad([2, 4, 6])
# Out:
# False

# %% [markdown]
# QUESTION-9

# %%
call_count = 0
def gcd(m, n):
  global call_count
  call_count += 1

  (a, b) = (max(m,n), min(m,n))
  if a % b == 0:
    return(b)
  else:
    return(gcd(b, a % b))

print(gcd(24, 130))
print(call_count)
# Out:
# 2
# 4

# %%
print(10%4)
# Out:
# 2

# %% [markdown]
# QUESTION-11

# %%
def fun(n):
  if n == 0:
    return 0
  return (n % 10) + fun(n // 100)

fun(4527)
# Out:
# 12

# %% [markdown]
# QUESTION-12

# %%
def fun(n):
  if n == 0:
    return 0
  if (n % 10) % 2 == 0:
    return 1 + fun(n // 10)
  else:
    return fun(n // 10)
fun(2399488)
# Out:
# 4

# %% [markdown]
# QUESTION-13

# %%
def fun(n):
  if n <= 1:
    return 0
  return fun(n - 1) + fun(n - 2)

fun(5)
# Out:
# 177

# %% [markdown]
# QUESTION-14

# %%
def fun(n):
  if n <= 1:
    return 0
  if n % 2 == 0:
    return fun(n//2)
  else:
    return 1 + fun(n // 2) + fun(n // 2)

fun(18)
# Out:
# 1

# %% [markdown]
# QUESTION-15

# %%
class Box:
  def __init__(self, size):
    self.size = size
  def double(self):
    self.size = self.size * 2


x = Box(5)
y = x
y.double()
x.double()

print(x.size, y.size)
# Out:
# 20 20
