# %% [markdown]
# <a href="https://colab.research.google.com/github/24f3003879/PDSA/blob/main/PDSA_WEEK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Maximum edges in an undirected simple graph with n vertices = n(n−1)/2

# %% [markdown]
# # For any undirected graph:
#
# Sum of all degrees=2E
# 	​
#
#
# where E = number of edges.

# %% [markdown]
# #For an adjacency matrix:
#
# ROW → Out-degree
#
#
# COLUMN → In-degree

# %% [markdown]
# #Algorithm	Data Structure	Rule
#
# BFS -> 	Queue	 -> FIFO
#
# DFS -> 	Stack	 -> LIFO
